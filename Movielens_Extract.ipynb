# %%
#importing dependencies
import pandas as pd

# %%
#pulling kaggle data into pandas dataframe
movies_metadata = pd.read_csv('/Users/richellelong/Desktop/Movies-ETL/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('/Users/richellelong/Desktop/Movies-ETL/ratings.csv')

# %%
#inspecting five random samples from movies_metadata
movies_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection  budget  \
# 855    False                   NaN       0
# 24102  False                   NaN  500000
# 19907  False                   NaN       1
# 25417  False                   NaN       0
# 12800  False                   NaN       0
#
#                                                   genres homepage      id  \
# 855    [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...      NaN   12559
# 24102  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN   83188
# 19907  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  220106
# 25417  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN  118134
# 12800  [{'id': 53, 'name': 'Thriller'}, {'id': 35, 'n...      NaN   12416
#
#          imdb_id original_language             original_title  \
# 855    tt0116311                en                  First Kid
# 24102  tt1618372                en              Camel Spiders
# 19907  tt0792984                fr  On ne devrait pas exister
# ...

# %%
#inspecting five random samples from movies_metadata
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 16079701  167306     1028     3.0  1096558709
# 25081045  260973     2859     4.0  1423269562
# 9184871    94845    56367     5.0  1293109545
# 5248729    54075     2414     3.5  1225838983
# 415789      4345   120635     2.5  1438961414
